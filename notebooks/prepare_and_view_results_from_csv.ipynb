# %%
import os

# Specify the directory path
directory_path = '/data/radnav/rad_nav_datasets/WILK_BASEMENT'

# List all files in the directory
print(os.listdir(directory_path))
# for filename in os.listdir(directory_path):
    # file_path = os.path.join(directory_path, filename)
    # if os.path.isfile(file_path):
    #     print(filename)
# Out:
# ['wilk_basement_1', 'wilk_basement_2']

# %%
import sys
sys.path.append("../")

from odometry.analyzers.analyzer import Analyzer

analyzer = Analyzer()

analyzer.show_cumulative_summary_from_csvs(
    save_folder="/home/david/Documents/odometry/scripts/Results"
)
# Out:
# /home/david/.cache/pypoetry/virtualenvs/odometry-JJ4jnFPp-py3.11/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#              Metric  Absolute position (m)  Relative position (m)  \
# 0              Mean               0.186618               0.011342
# 1          Variance               0.018169               0.000323
# 2            Median               0.160236               0.006195
# 3  0.9th percentile               0.367412               0.026462
#
#    Final position (m)  Absolute heading (deg)  Relative heading (deg)  \
# 0            0.121839                3.085322                0.311773
# 1            0.005628                7.159633                0.261976
# 2            0.109063                2.347894                0.132242
# 3            0.225301                7.022863                0.850179
#
# ...
