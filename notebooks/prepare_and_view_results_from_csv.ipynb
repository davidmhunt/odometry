# %%
import os

# Specify the directory path
directory_path = '/data/radnav/radCloud_comp_datasets/WILK'

# List all files in the directory
print(os.listdir(directory_path))
# for filename in os.listdir(directory_path):
    # file_path = os.path.join(directory_path, filename)
    # if os.path.isfile(file_path):
    #     print(filename)
# Out:
# ['WILK_1', 'WILK_2', 'WILK_3']

# %%
import sys
sys.path.append("../")

from odometry.analyzers.analyzer import Analyzer

analyzer = Analyzer()

analyzer.show_cumulative_summary_from_csvs(
    save_folder="/home/david/Documents/odometry/scripts/radarHD09042024/Results"
)
# Out:
#              Metric  Absolute position (m)  Relative position (m)  \
# 0              Mean               1.480738               0.026099
# 1             stdev               1.671400               0.031780
# 2            Median               0.723251               0.019350
# 3  0.9th percentile               3.876572               0.053884
#
#    Final position (m)  Absolute heading (deg)  Relative heading (deg)  \
# 0            3.203443                6.825470                0.109381
# 1            2.789806                5.577879                0.114870
# 2            2.347508                5.657896                0.075301
# 3            5.900733               14.736824                0.247336
#
#    Final heading (deg)
# 0            10.173686
# 1             5.694963
# 2             7.900078
# 3            16.973349
# total distance: 257.08502525097504
# average trial distance: 36.726432178710716
# total frames: 7806.0
# average frames per trial: 1115.142857142857
