# %%
import os

# Specify the directory path
directory_path = '/data/radnav/radCloud_comp_datasets/WILK'

# List all files in the directory
print(os.listdir(directory_path))
# for filename in os.listdir(directory_path):
    # file_path = os.path.join(directory_path, filename)
    # if os.path.isfile(file_path):
    #     print(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 directory_path = '/data/radnav/radCloud_comp_datasets/WILK'
#       6 # List all files in the directory
# ----> 7 print(os.listdir(directory_path))
#       8 # for filename in os.listdir(directory_path):
#       9     # file_path = os.path.join(directory_path, filename)
#      10     # if os.path.isfile(file_path):
#      11     #     print(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/radnav/radCloud_comp_datasets/WILK'

# %%
import sys
sys.path.append("../")

from odometry.analyzers.analyzer import Analyzer

#specify the save folder
# save_folder ="/home/david/Documents/odometry/scripts/radarHD02282025/Results"
# save_folder ="/home/david/Documents/odometry/scripts/radCloud02282025/Results"
# save_folder ="/home/david/Documents/odometry/scripts/NaiveRadar0228205/Results"
# save_folder = "/home/david/Documents/odometry/scripts/RaGNNarok/RaGNNarok_1fp_20fh_0_50_th_5mRng_0_2_res_10fp/Results_seen"
# save_folder = "/home/david/Documents/odometry/scripts/IcaRAus_gnn_50fh_train/Results"
save_folder = "/home/david/Documents/odometry/scripts/IcaRAus_gnn_two_stream_IcaRAus_ds_50fh_k_4_train/Results"
print(save_folder)
#initialize the analyzer
analyzer = Analyzer()

analyzer.show_cumulative_summary_from_csvs(
    save_folder=save_folder
)
# Out:
# /home/david/Documents/odometry/scripts/IcaRAus_gnn_two_stream_IcaRAus_ds_50fh_k_4_train/Results
#              Metric  Absolute position (m)  Relative position (m)  \
# 0              Mean               0.113450               0.002268
# 1             stdev               0.063335               0.002392
# 2            Median               0.104039               0.001995
# 3  0.9th percentile               0.192622               0.003985
#
#    Final position (m)  Absolute heading (deg)  Relative heading (deg)  \
# 0            0.066742                1.597451                0.030954
# 1            0.038054                1.123202                0.043398
# 2            0.056145                1.449863                0.023947
# 3            0.128983                3.006021                0.062863
#
#    Final heading (deg)  Average Point Cloud Dist  Max Point Cloud Dist  \
# 0             1.051664                  0.228571              1.621506
# 1             0.686378                  0.089630              0.559529
# 2             1.096448                  0.210433              1.658256
# 3             1.971022                  0.343642              2.363708
#
#    Number of Points  Quality Points
# 0       2016.104677     1816.734367
# 1        449.624104      447.026817
# 2       2058.000000     1827.000000
# 3       2555.000000     2409.000000
# total distance: 490.1733597439814
# average trial distance: 122.54333993599535
# total frames: 12080.0
# average frames per trial: 3020.0
# max position error: 0.4640245245153649

# %%
from odometry.plotting.plotter_analyzer import PlotterAnalyzer
import matplotlib.pyplot as plt
plotter = PlotterAnalyzer()

#get absolute position errors
absolute_errors_pos,absolute_errors_heading = \
    analyzer.get_absolute_errors_from_csvs(save_folder)

fig,ax = plt.subplots(figsize=(5,1.2))

plotter.plot_error_histogram(
    errors=absolute_errors_pos,
    bins=50,
    ax=ax,
    show=False
)
ax.set_title("")
ax.set_xlabel("ATE Error (m)")
# Out:
# Max: 7.408940397350994, sum: 100.0
# Text(0.5, 0, 'ATE Error (m)')

# %%
from odometry.plotting.plotter_analyzer import PlotterAnalyzer
import matplotlib.pyplot as plt
plotter = PlotterAnalyzer()

#get absolute position errors
relative_errors_pos,relative_errors_heading = \
    analyzer.get_relative_errors_from_csvs(save_folder)

fig,ax = plt.subplots(figsize=(10,1.2))

plotter.plot_error_histogram(
    errors=relative_errors_pos,
    bins=100,
    ax=ax,
    show=False
)
ax.set_title("")
ax.set_xlabel("RTE Error (m)")
# Out:
# Max: 28.47234263915381, sum: 100.0
# Text(0.5, 0, 'RTE Error (m)')
